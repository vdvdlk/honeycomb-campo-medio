# %%
import matplotlib.pyplot as plt
import numpy as np
# from scipy.linalg.lapack import zheev
from scipy.stats import logistic

# from FDhoney_New import funcao_FD

# %matplotlib widget

# %%
# matriz = np.array([
#     [-1, 1-2j, 0],
#     [1+2j, 0, 0-1j],
#     [0, 0+1j, 1]
# ])

# w, v = np.linalg.eigh(matriz)

# print(v)
# print()
# print(np.transpose(np.conjugate(v)))
# print()
# print(np.linalg.inv(v))
# print()

# valor_esp_cjcj(w, v)

# # M = np.matmul(
# #     np.conjugate(np.transpose(v)),
# #     v
# # )

# # np.conjugate(v[0, 0]) * v[0, 0] + np.conjugate(v[1, 0]) * v[1, 0] + np.conjugate(v[2, 0]) * v[2, 0]

# %%
x = np.linspace(0, 2)
y = logistic.sf(x)
y_2 = 1.0 / (1.0 + np.exp(x))
# y_3 = funcao_FD(E=x, mu=0, beta=1)

plt.xlim(0, 2)
plt.ylim(0, 0.5)
plt.plot(x, y)
# plt.plot(x, y_2)
# plt.plot(x, y_3)

print(y)
# Out:
# [0.5        0.48979733 0.47960316 0.46942595 0.4592741  0.44915594
#  0.43907968 0.4290534  0.41908502 0.40918225 0.39935262 0.3896034
#  0.37994165 0.3703741  0.36090725 0.35154728 0.34230003 0.33317105
#  0.32416553 0.31528835 0.30654399 0.29793663 0.28947007 0.28114775
#  0.27297278 0.2649479  0.25707552 0.2493577  0.24179617 0.23439234
#  0.2271473  0.22006183 0.21313642 0.2063713  0.19976638 0.19332137
#  0.18703569 0.18090855 0.17493894 0.16912564 0.16346724 0.15796217
#  0.15260866 0.14740484 0.14234865 0.13743793 0.13267042 0.12804374
#  0.12355542 0.11920292]

# %%
array = np.array([[-1, -2, 3-4j], [4, -5, 6], [-7, 8, 9]])


np.abs(array)**2
# Out:
# array([[ 1.,  4., 25.],
#        [16., 25., 36.],
#        [49., 64., 81.]])

# %%
array.shape[1]
# Out:
# 3
